# %%
# Clone repo
# !git clone https://github.com/arnoldzhou03/ecs170-bot.git

# Set up environment
# !apt-get update
# !apt-get install -y python3.10-venv
# !pip install requests==2.31.0

# !python3 -m venv ecs170-bot/venv

# Install dependencies
# !source ecs170-bot/venv/bin/activate
# !pip install -r ecs170-bot/requirements.txt

# Navigate to the bot directory
# %cd ecs170-bot

# Start the bot
# !python3 lichess-bot.py -u
# Out:
# Cloning into 'ecs170-bot'...
# remote: Enumerating objects: 4168, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 4168 (delta 111), reused 154 (delta 94), pack-reused 3970
# Receiving objects: 100% (4168/4168), 1.29 MiB | 4.15 MiB/s, done.
# Resolving deltas: 100% (2749/2749), done.
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...
